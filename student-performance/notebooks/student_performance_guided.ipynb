# %% [markdown]
# # Student Performance — Complete Exercise Notebook
#
# This workbook covers Exercises 1–10 and both bonus activities from the Student Performance brief.
#
# Each section below is an executable notebook cell. The Python exercise scripts remain the canonical implementations, and the notebook runs those implementations so the notebook and script results stay in sync.

# %% [markdown]
# ## Setup and data preview

# %%
from pathlib import Path
import runpy
import sys

import pandas as pd
from IPython.display import Image, display

for candidate in (Path.cwd(), *Path.cwd().parents):
    if (candidate / "common" / "data_loading.py").exists():
        PROJECT_ROOT = candidate
        break
else:
    raise FileNotFoundError("Could not locate the repository root.")

sys.path.insert(0, str(PROJECT_ROOT))
from common.data_loading import load_dataset

OUTPUT_DIR = PROJECT_ROOT / "student-performance" / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

def run_exercise(script_name, output_name):
    """Run one canonical exercise and display its saved chart."""
    script_path = PROJECT_ROOT / "student-performance" / "exercises" / script_name
    print(f"Running: {script_path.relative_to(PROJECT_ROOT)}")
    runpy.run_path(str(script_path), run_name="__main__")
    chart_path = OUTPUT_DIR / output_name
    if not chart_path.is_file():
        raise FileNotFoundError(f"Expected chart was not created: {chart_path}")
    display(Image(filename=str(chart_path)))

_, raw_df = load_dataset(
    "student-performance/dataset/student_performance.csv",
    list(pd.read_csv(PROJECT_ROOT / "student-performance/dataset/student_performance.csv", nrows=0).columns),
)
analysis_df = raw_df.copy()
print(f"Rows: {len(analysis_df)}")
display(analysis_df.head())
# Out:
# Rows: 10
#   Student  Gender  Study_Hours  Attendance  Math_Score  English_Score  \
# 0    John    Male            2          85          70             75
# 1    Anna  Female            4          92          88             90
# 2   David    Male            1          70          60             65
# 3    Lisa  Female            5          95          92             94
# 4     Tom    Male            3          80          75             70
#
#    Science_Score
# 0             80
# 1             85
# 2             58
# 3             90
# 4             72

# %% [markdown]
# The notebook uses an in-memory copy for exploration. The source CSV remains unchanged.

# %% [markdown]
# ## Exercise 1 — Math Scores Bar Chart
#
# Compare student names on the x-axis with Math scores on the y-axis. The chart includes a title, axis labels, and a custom bar color.
#
# Implementation: `01_math_scores_bar.py`

# %%
run_exercise("01_math_scores_bar.py", "01_math_scores_bar.png")
# Out:
# Running: student-performance/exercises/01_math_scores_bar.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/01_math_scores_bar.png
# Students plotted: 10
# Score range: 60–95

# %% [markdown]
# ## Exercise 2 — English Scores Horizontal Bar Chart
#
# Compare English scores with a horizontal bar chart, custom color, and grid.
#
# Implementation: `02_english_scores_horizontal_bar.py`

# %%
run_exercise("02_english_scores_horizontal_bar.py", "02_english_scores_horizontal_bar.png")
# Out:
# Running: student-performance/exercises/02_english_scores_horizontal_bar.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/02_english_scores_horizontal_bar.png
# Students plotted: 10
# Score range: 65–96

# %% [markdown]
# ## Exercise 3 — Gender Pie Chart
#
# Show the number of Male and Female students with percentages, colors, and a title.
#
# Implementation: `03_gender_pie.py`

# %%
run_exercise("03_gender_pie.py", "03_gender_pie.png")
# Out:
# Running: student-performance/exercises/03_gender_pie.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/03_gender_pie.png
# Gender counts: {'Male': 5, 'Female': 5}
# Total students: 10

# %% [markdown]
# ## Exercise 4 — Science Scores Line Chart
#
# Plot students against Science scores using markers, a changed line style, and a legend.
#
# Implementation: `04_science_scores_line.py`

# %%
run_exercise("04_science_scores_line.py", "04_science_scores_line.png")
# Out:
# Running: student-performance/exercises/04_science_scores_line.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/04_science_scores_line.png
# Students plotted: 10
# Score range: 58–94

# %% [markdown]
# ## Exercise 5 — Multiple Subject Lines
#
# Compare Math, English, and Science scores on one chart with different colors, a legend, and grid.
#
# Implementation: `05_subject_scores_multiple_lines.py`

# %%
run_exercise("05_subject_scores_multiple_lines.py", "05_subject_scores_multiple_lines.png")
# Out:
# Running: student-performance/exercises/05_subject_scores_multiple_lines.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/05_subject_scores_multiple_lines.png
# Students plotted: 10
# Subjects plotted: ['Math', 'English', 'Science']

# %% [markdown]
# ## Exercise 6 — Math Score Histogram
#
# Explore the Math score distribution with five bins and labeled axes.
#
# Implementation: `06_math_score_histogram.py`

# %%
run_exercise("06_math_score_histogram.py", "06_math_score_histogram.png")
# Out:
# Running: student-performance/exercises/06_math_score_histogram.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/06_math_score_histogram.png
# Number of bins: 5
# Bin counts: [1, 2, 2, 1, 4]
# Bin edges: [60.0, 67.0, 74.0, 81.0, 88.0, 95.0]

# %% [markdown]
# ## Exercise 7 — Study Hours vs Math Scores
#
# Use a scatter plot to explore whether more study hours are associated with higher Math scores.
#
# Implementation: `07_study_hours_math_scatter.py`

# %%
run_exercise("07_study_hours_math_scatter.py", "07_study_hours_math_scatter.png")
# Out:
# Running: student-performance/exercises/07_study_hours_math_scatter.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/07_study_hours_math_scatter.png
# Students plotted: 10
# Pearson correlation (extension): 0.985

# %% [markdown]
# ## Exercise 8 — Attendance vs Science Scores
#
# Use a colored scatter plot with a custom marker style and larger marker size.
#
# Implementation: `08_attendance_science_scatter.py`

# %%
run_exercise("08_attendance_science_scatter.py", "08_attendance_science_scatter.png")
# Out:
# Running: student-performance/exercises/08_attendance_science_scatter.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/08_attendance_science_scatter.png
# Students plotted: 10
# Pearson correlation (extension): 0.973

# %% [markdown]
# ## Exercise 9 — Average Scores Bar Chart
#
# Calculate and chart the average Math, English, and Science scores.
#
# Implementation: `09_average_scores_bar.py`

# %%
run_exercise("09_average_scores_bar.py", "09_average_scores_bar.png")
# Out:
# Running: student-performance/exercises/09_average_scores_bar.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/09_average_scores_bar.png
# Average scores:
# - Math: 80.0
# - English: 81.6
# - Science: 80.5

# %% [markdown]
# ## Exercise 10 — Mini Dashboard
#
# Combine a bar chart, pie chart, histogram, and scatter plot using subplots.
#
# Implementation: `10_mini_dashboard.py`

# %%
run_exercise("10_mini_dashboard.py", "10_mini_dashboard.png")
# Out:
# Running: student-performance/exercises/10_mini_dashboard.py
# Saved dashboard: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/10_mini_dashboard.png
# Subplots created: 4
# Layout method: plt.subplot()

# %% [markdown]
# ## Bonus 1 — Values on Bars
#
# Add score values above the bars to make the chart easier to read.
#
# Implementation: `bonus_01_value_labels.py`

# %%
run_exercise("bonus_01_value_labels.py", "bonus_01_math_scores_value_labels.png")
# Out:
# Running: student-performance/exercises/bonus_01_value_labels.py
# Saved chart: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/bonus_01_math_scores_value_labels.png
# Labels added: 10

# %% [markdown]
# ## Bonus 2 — Style Experiments
#
# Practice alternative colors, markers, line styles, and figure-size choices.
#
# Implementation: `bonus_02_style_experiments.py`

# %%
run_exercise("bonus_02_style_experiments.py", "bonus_02_style_experiments.png")
# Out:
# Running: student-performance/exercises/bonus_02_style_experiments.py
# Saved style board: /home/wsl-lenovo/ifa-project/DA-python/data-visualization-with-matplotlib/student-performance/outputs/bonus_02_style_experiments.png
# Experiments: colors, markers, linestyles, figure size

# %% [markdown]
# ## Interpretation reminder
#
# The study-hours and attendance charts show associations in a small classroom dataset. They do not prove that one variable caused a score to change.
